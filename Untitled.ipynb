# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import json
from pathlib import Path 
from sklearn.preprocessing import StandardScaler

# %%
#Reading Data
df_listings = pd.read_csv('data/listings.csv')
df_calendar = pd.read_csv('data/calendar.csv')
df_reviews = pd.read_csv('data/reviews.csv')

# %%
print("There are %s listings in the listings.csv" % df_listings.shape[0])
# Out:
# There are 3818 listings in the listings.csv

# %%
def remove_dollar_sign(x):
    if (type(x) == str):
        x = x.replace('$','')
        x = x.replace(',','')
        return float(x)
    return (x)
def transform_percent(x):
    if (type(x) == str):
        x = x.replace('%','')
        return float(x)/100
    return (x)
def transform_boolean(x):
    if (type(x) == str):
        if (x == "f"): 
            return float(0)
        elif (x == "t"):
            return float(1)

fill_mean = lambda col: col.fillna(col.mean())

# %%
# correlation between features
#prepare the data

df_listings['price']=df_listings['price'].map(lambda x: remove_dollar_sign(x))
df_listings['weekly_price']=df_listings['weekly_price'].map(lambda x: remove_dollar_sign(x))
df_listings['monthly_price']=df_listings['monthly_price'].map(lambda x: remove_dollar_sign(x))
df_listings['security_deposit']=df_listings['security_deposit'].map(lambda x: remove_dollar_sign(x))

df_listings['host_response_rate']=df_listings['host_response_rate'].map(lambda x: transform_percent(x))
df_listings['host_acceptance_rate']=df_listings['host_acceptance_rate'].map(lambda x: transform_percent(x))
df_listings['host_is_superhost'] = df_listings['host_is_superhost'].map(lambda x: transform_boolean(x))

df_listings_numeric_only = df_listings.select_dtypes(include=[np.number])
df_listings_numeric_only= df_listings_numeric_only.drop(['license','latitude','longitude','id','scrape_id','host_id'],axis=1)
df_listings_numeric_only.to_csv(Path('out.csv'))
df_listings_numeric_only = df_listings_numeric_only.apply(fill_mean,axis=0)
df_listings_numeric_only.to_csv(Path('out2.csv'))

corr = df_listings_numeric_only.corr()
#A=corr.unstack().sort_values(ascending=False)
df_listings_numeric_only.head()
#print('The correlation of the  against all:\n', A.price[1:-1])

#How does the number of ammenities influence the price
res = df_listings.amenities.apply(lambda s: s.replace('{','').replace('}','').replace('"',''))
amenities_set = set()
for elem in res:
    amenities_set.update(elem.split(','))
amenities_set=[x for x in amenities_set if x]

dictionary = {key:list() for key in amenities_set}
print(dictionary.keys())
for all_amenities in res:
    has_amenity = []
    for elem in all_amenities.split(','):
        if (elem and not dictionary.get(elem)):
            dictionary.update({elem:[True]})
        else:
            if elem: 
                dictionary.get(elem).append(True)
        has_amenity.append(elem)
    #print(has_amenity)
    for key in dictionary.keys():
        if key not in has_amenity:
            dictionary.get(key).append(False)
    
df_amenities = pd.DataFrame(dictionary)
#result = df_listings_numeric_only
#df_listings_numeric_only.info()
df_listings_numeric_with_amentities = pd.concat([df_amenities, df_listings_numeric_only], axis=1, join='inner')
#result.to_csv(Path('out3.csv'))
#A=result.corr().unstack().sort_values(ascending=False)
#print('The correlation of the  against all:\n', A.price[0:].to_string())
#result.head()
#for key,value in dictionary.items():
#    print("%d %s" % (len(value),key))
    #print(value)
#c = a.join(b)
#print(b)
#df_listings.info()
#c.head()
# Out:
# dict_keys(['Heating', 'Lock on Bedroom Door', 'Air Conditioning', 'Carbon Monoxide Detector', 'Buzzer/Wireless Intercom', 'Shampoo', 'Family/Kid Friendly', 'Internet', 'Pool', 'Elevator in Building', 'Iron', 'Hangers', 'Hot Tub', 'Washer', 'Laptop Friendly Workspace', 'Pets Allowed', 'Cat(s)', 'Suitable for Events', 'Smoking Allowed', 'Pets live on this property', 'Dog(s)', 'Free Parking on Premises', 'Breakfast', 'Wireless Internet', 'Other pet(s)', 'TV', 'Doorman', 'Essentials', 'Hair Dryer', 'Kitchen', 'Cable TV', 'Smoke Detector', 'Safety Card', 'Indoor Fireplace', 'Gym', 'Wheelchair Accessible', 'Dryer', 'First Aid Kit', 'Washer / Dryer', '24-Hour Check-in', 'Fire Extinguisher'])

# %%
def train_model_and_predict(data, prediction_param):
    y = data[prediction_param]
    try:
        X = data.drop([prediction_param],axis=1)
    except:
        print("param %s no longer in data" % (prediction_param))
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state=42)
    sc_X = StandardScaler()

    X_train = sc_X.fit_transform(X_train)
    X_test = sc_X.transform(X_test)

    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train) 

    y_test_pred = lr_model.predict(X_test)
    y_train_pred = lr_model.predict(X_train)
    #residual plot
    #plt.scatter(y_train_pred,  y_train_pred - y_train,c='blue', marker='o', label='Training data')
    plt.scatter(y_test_pred,  y_test_pred - y_test, c='lightgreen', marker='s', label='Test data')
    plt.xlabel('Predicted values')
    plt.ylabel('Residuals')
    plt.legend(loc='upper left')
    plt.show()
    # Print model evaluation scores for training and test, the larger the r squared the better the model
    print('Traning Data:')
    print('r-sqaured score: %.3f' % r2_score(y_train, y_train_pred))
    print('mean-sqaured error: %.3f' % mean_squared_error(y_train, y_train_pred))
    print('---')
    print('Test Data:')
    print('r-sqaured score: %.3f' % r2_score(y_test, y_test_pred))
    print('mean-sqaured error: %.3f' % mean_squared_error(y_test, y_test_pred))
    print('---')
    #coefficients
    cdf = pd.DataFrame(lr_model.coef_, X.columns, columns=['Coefficients'])
    print(cdf.unstack().sort_values(ascending=False).to_string())

# %%
#X = X[X.columns.drop(list(X.filter(regex='price')))]
X = df_listings_numeric_with_amentities.drop(['host_acceptance_rate','weekly_price','monthly_price','host_listings_count'],axis=1)
train_model_and_predict(X, 'price')
# Out:
# Traning Data:
# r-sqaured score: 0.546
# mean-sqaured error: 3617.468
# ---
# Test Data:
# r-sqaured score: 0.565
# mean-sqaured error: 3722.590
# ---
# Coefficients  accommodates                      28.589978
#               bedrooms                          20.106746
#               bathrooms                         14.442849
#               security_deposit                   8.502597
#               Elevator in Building               8.498415
#               Doorman                            5.094840
#               review_scores_location             4.502035
#               Cable TV                           4.354440
#               review_scores_cleanliness          4.071258
#               Dog(s)                             3.810235
#               review_scores_accuracy             3.785141
#               host_is_superhost                  3.733111
#               Hot Tub                            3.678917
#               guests_included                    3.326973
#               Laptop Friendly Workspace          2.721983
#               Air Conditioning                   2.688846
#               review_scores_rating               2.569630
#               availability_365                   2.523748
#               Kitchen                            2.070623
#               Buzzer/Wireless Intercom           2.006742
#               Hair Dryer                         1.773729
#               review_scores_communication        1.445575
#               Dryer                              1.380181
#               First Aid Kit                      1.187888
#               Shampoo                            0.932801
#               availability_30                    0.864583
#               Indoor Fireplace                   0.802495
#               Internet                           0.798023
#               Other pet(s)                       0.766414
#               beds                               0.710224
#               Safety Card                        0.498904
#               Pets Allowed                       0.317826
#               Suitable for Events                0.287956
#               TV                                 0.128279
#               Wheelchair Accessible              0.098151
#               minimum_nights                     0.085812
#               host_total_listings_count          0.072183
#               Pool                               0.032719
#               square_feet                        0.013229
#               Essentials                        -0.048621
#               host_response_rate                -0.083662
#               Cat(s)                            -0.133055
#               Washer / Dryer                    -0.578780
#               availability_90                   -0.667549
#               Gym                               -0.706424
#               Smoke Detector                    -1.025443
#               Family/Kid Friendly               -1.040642
#               Carbon Monoxide Detector          -1.084717
#               Lock on Bedroom Door              -1.170263
#               Heating                           -1.314964
#               Fire Extinguisher                 -1.322851
#               maximum_nights                    -1.341771
#               Wireless Internet                 -1.567741
#               review_scores_checkin             -1.912103
#               number_of_reviews                 -1.974014
#               Smoking Allowed                   -1.974198
#               availability_60                   -1.997835
#               Iron                              -2.021500
#               Breakfast                         -2.342652
#               calculated_host_listings_count    -3.287927
#               24-Hour Check-in                  -3.308037
#               Free Parking on Premises          -3.498307
#               Hangers                           -3.682543
#               Pets live on this property        -3.819443
#               Washer                            -4.021657
#               reviews_per_month                 -6.511195
#               review_scores_value               -9.468776

# %%
#X = X[X.columns.drop(list(X.filter(regex='price')))]
X = df_listings_numeric_with_amentities.drop(['host_acceptance_rate'],axis=1)
train_model_and_predict(X, 'review_scores_rating')
# Out:
# Traning Data:
# r-sqaured score: 0.650
# mean-sqaured error: 11.960
# ---
# Test Data:
# r-sqaured score: 0.689
# mean-sqaured error: 12.717
# ---
# Coefficients  host_total_listings_count         4.365104e+12
#               review_scores_value               1.988224e+00
#               review_scores_cleanliness         1.416474e+00
#               review_scores_accuracy            1.198168e+00
#               review_scores_communication       6.293439e-01
#               review_scores_checkin             4.358034e-01
#               review_scores_location            3.546115e-01
#               availability_90                   2.509153e-01
#               host_is_superhost                 2.287109e-01
#               Elevator in Building              2.230078e-01
#               Safety Card                       2.126367e-01
#               price                             1.904491e-01
#               Pets live on this property        1.855541e-01
#               Laptop Friendly Workspace         1.799313e-01
#               Suitable for Events               1.379561e-01
#               Shampoo                           1.122813e-01
#               bathrooms                         1.043555e-01
#               Doorman                           9.322204e-02
#               Wireless Internet                 9.307773e-02
#               minimum_nights                    8.710256e-02
#               security_deposit                  8.368343e-02
#               First Aid Kit                     7.951143e-02
#               Other pet(s)                      7.909946e-02
#               availability_30                   7.180051e-02
#               Kitchen                           6.968973e-02
#               Smoking Allowed                   6.561403e-02
#               Dryer                             6.189903e-02
#               bedrooms                          6.135013e-02
#               square_feet                       6.133795e-02
#               Cable TV                          6.088765e-02
#               Air Conditioning                  4.527578e-02
#               Fire Extinguisher                 4.508755e-02
#               Indoor Fireplace                  4.507444e-02
#               Pets Allowed                      4.292061e-02
#               host_response_rate                4.169739e-02
#               Internet                          2.759692e-02
#               24-Hour Check-in                  8.142513e-03
#               Family/Kid Friendly               7.823536e-03
#               Washer / Dryer                    7.334757e-03
#               Iron                              4.689163e-03
#               beds                              3.173205e-03
#               Smoke Detector                    9.639227e-04
#               Washer                           -3.480309e-03
#               availability_365                 -4.172266e-03
#               Heating                          -1.378298e-02
#               Lock on Bedroom Door             -1.636943e-02
#               TV                               -1.746631e-02
#               number_of_reviews                -1.854449e-02
#               Hot Tub                          -3.109249e-02
#               Pool                             -3.180402e-02
#               Carbon Monoxide Detector         -3.391988e-02
#               Gym                              -3.705684e-02
#               weekly_price                     -4.817617e-02
#               Breakfast                        -5.151346e-02
#               Essentials                       -5.152627e-02
#               Free Parking on Premises         -5.203265e-02
#               maximum_nights                   -5.669652e-02
#               Buzzer/Wireless Intercom         -6.020015e-02
#               Wheelchair Accessible            -6.458498e-02
#               Dog(s)                           -8.398280e-02
#               guests_included                  -9.129188e-02
#               accommodates                     -9.583977e-02
#               Hangers                          -9.714126e-02
#               monthly_price                    -1.023873e-01
#               Hair Dryer                       -1.430203e-01
#               Cat(s)                           -1.530252e-01
#               calculated_host_listings_count   -1.972113e-01
#               reviews_per_month                -2.883571e-01
#               availability_60                  -3.546953e-01
#               host_listings_count              -4.365104e+12
